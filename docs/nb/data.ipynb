# %% [markdown]
# # Figure(s) that demonstrate the data

# %%
import os, glob
import numpy as np
from tqdm.notebook import tqdm, trange

# %%
import torch
from haloflow import data as D
from haloflow import util as U

# %%
import corner as DFM
# --- plotting ---
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rcParams['text.usetex'] = True
mpl.rcParams['font.family'] = 'serif'
mpl.rcParams['axes.linewidth'] = 1.5
mpl.rcParams['axes.xmargin'] = 1
mpl.rcParams['xtick.labelsize'] = 'x-large'
mpl.rcParams['xtick.major.size'] = 5
mpl.rcParams['xtick.major.width'] = 1.5
mpl.rcParams['ytick.labelsize'] = 'x-large'
mpl.rcParams['ytick.major.size'] = 5
mpl.rcParams['ytick.major.width'] = 1.5
mpl.rcParams['legend.frameon'] = False

# %%
y0, x0 = D.get_subhalos('train', 'mags', snapshot=91)

# %%
print('%i central galaxies in the training dataset' % (y0.shape[0]/4))
# Out:
# 1742 central galaxies in the training dataset

# %%
ytest, xtest = D.get_subhalos('test', 'mags', snapshot=91)

# %%
ytest.shape
# Out:
# (500, 2)

# %%
np.min(y0, axis=0)
# Out:
# array([9.00035, 6.13393])

# %%
fig = plt.figure(figsize=(6,6))
sub = fig.add_subplot(111)
sub.scatter(y0[:,0], y0[:,1], s=1, label='Training Galaxies')
sub.scatter(ytest[:,0], ytest[:,1], s=3, label='Testing Galaxies')
sub.legend(loc='lower right', handletextpad=0, markerscale=10, fontsize=20)
sub.set_xlabel(r'$\log M_*$', fontsize=25)
sub.set_xlim(9., 12.5)
sub.set_ylabel(r'$\log M_h$', fontsize=25)
sub.set_ylim(9., None)
# Out:
# (9.0, 14.6468785)

# %%
plt.hist(y0[:,0])
# Out:
# (array([2696., 1600.,  992.,  752.,  452.,  308.,   92.,   56.,   16.,
#            4.]),
#  array([ 9.00035 ,  9.373735,  9.74712 , 10.120505, 10.49389 , 10.867275,
#         11.24066 , 11.614045, 11.98743 , 12.360815, 12.7342  ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(y0[:,1], range=(10, 15), bins=30)
plt.vlines(11.1, 0, 1600, color='k', linestyle='--')
plt.xlim(10., 15)
# Out:
# (10.0, 15.0)
